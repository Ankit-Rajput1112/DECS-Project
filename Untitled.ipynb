# %%
# Set Git username and email

# !git config --global user.name "Ankit-Rajput1112"
# !git config --global user.email "rajkumarankit9070@gmail.com"

# %%
# Remove existing origin remote 
# !git remote remove origin

# Add origin remote
# !git remote add origin https://github.com/Ankit-Rajput1112/DECS-Project.git
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# Initialize Git repo
# !git init
# Out:
# Initialized empty Git repository in C:/Users/91889/Desktop/DECS/Project/kv_server_phase1_final/.git/

# %%
# !git remote add origin https://github.com/Ankit-Rajput1112/DECS-Project.git

# %%
# !git add .
# Out:
# warning: in the working copy of '.ipynb_checkpoints/Untitled-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.vscode/c_cpp_properties.json', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.vscode/launch.json', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.vscode/settings.json', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Makefile', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'README.md', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Untitled.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'include/httplib.h', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'include/json.hpp', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'init_sql.sh', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'lru_cache.h', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'pg_store.h', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'server.cpp', LF will be replaced by CRLF the next time Git touches it

# %%
# !git commit -m "Initial commit"
# Out:
# [master (root-commit) c0a7550] Initial commit
#  14 files changed, 38254 insertions(+)
#  create mode 100644 .ipynb_checkpoints/Untitled-checkpoint.ipynb
#  create mode 100644 .vscode/c_cpp_properties.json
#  create mode 100644 .vscode/launch.json
#  create mode 100644 .vscode/settings.json
#  create mode 100644 Makefile
#  create mode 100644 README.md
#  create mode 100644 Untitled.ipynb
#  create mode 100644 include/httplib.h
#  create mode 100644 include/json.hpp
#  create mode 100644 init_sql.sh
#  create mode 100644 lru_cache.h
#  create mode 100644 pg_store.h
#  create mode 100644 server
#  create mode 100644 server.cpp

# %%
# Rename branch to main
# !git branch -M main

# Push branch to remote
# !git push -u origin main
# Out:
# branch 'main' set up to track 'origin/main'.
# To https://github.com/Ankit-Rajput1112/DECS-Project.git
#  * [new branch]      main -> main

# %%
# !git rm -f Untitled.ipynb
# Out:
# fatal: pathspec 'Untitled.ipynb' did not match any files

# %%
# !git rm -rf .vscode
# Out:
# fatal: pathspec '.vscode' did not match any files

# %%
# !git add-A
